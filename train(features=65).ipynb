# %%
import mahotas
import cv2

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import os
import glob

print(sys.path)
print(os.getcwd())
# Out:
# ['D:\\Study\\Project\\AOI', 'C:\\Users\\aaronlin\\.conda\\envs\\project_AOI\\python38.zip', 'C:\\Users\\aaronlin\\.conda\\envs\\project_AOI\\DLLs', 'C:\\Users\\aaronlin\\.conda\\envs\\project_AOI\\lib', 'C:\\Users\\aaronlin\\.conda\\envs\\project_AOI', '', 'C:\\Users\\aaronlin\\AppData\\Roaming\\Python\\Python38\\site-packages', 'C:\\Users\\aaronlin\\.conda\\envs\\project_AOI\\lib\\site-packages', 'C:\\Users\\aaronlin\\.conda\\envs\\project_AOI\\lib\\site-packages\\win32', 'C:\\Users\\aaronlin\\.conda\\envs\\project_AOI\\lib\\site-packages\\win32\\lib', 'C:\\Users\\aaronlin\\.conda\\envs\\project_AOI\\lib\\site-packages\\Pythonwin']
# D:\Study\Project\AOI

# %%
path_lst=[]
for f in glob.glob('Data(image)/train/full/*.png'): ###train_image改成放所有圖片的資料夾
    path_lst.append(f)
    
f1=f2=f3=f4=f5=f6=f7=f8=f9=f10=f11=f12=f13=np.empty(0)

for image in path_lst:
    img = cv2.imread(image)
    feature = mahotas.features.haralick(img).mean(axis =0)

    f1 = np.append(f1,feature[0])
    f2 = np.append(f2,feature[1])
    f3 = np.append(f3,feature[2])
    f4 = np.append(f4,feature[3])
    f5 = np.append(f5,feature[4])
    f6 = np.append(f6,feature[5])
    f7 = np.append(f7,feature[6])
    f8 = np.append(f8,feature[7])
    f9 = np.append(f9,feature[8])
    f10 = np.append(f10,feature[9])
    f11 = np.append(f11,feature[10])
    f12 = np.append(f12,feature[11])
    f13 = np.append(f13,feature[12])

# %%
df_full = pd.DataFrame([f1,f2,f3,f4,f5,f6,f7,f8,f9,f10,f11,f12,f13], 
             index = ['f1','f2','f3','f4','f5','f6','f7','f8','f9','f10','f11','f12','f13']).transpose()
df_full
# Out:
#             f1          f2        f3          f4        f5          f6  \
# 0     0.001354  659.317620  0.157167  391.132306  0.121252  346.768587
# 1     0.001497   91.209170  0.909179  502.079395  0.200690  358.785207
# 2     0.005265    3.084968  0.995852  371.720231  0.523585  357.885009
# 3     0.003159    4.283336  0.996857  681.378381  0.491811  413.949971
# 4     0.003536    2.498093  0.997002  416.623572  0.555521  406.948885
# ...        ...         ...       ...         ...       ...         ...
# 1495  0.001614   66.861090  0.950800  679.505644  0.215053  351.011115
# 1496  0.001704  364.121754  0.447507  329.527395  0.138495  332.144321
# 1497  0.001199   67.339221  0.949033  660.564422  0.211137  331.220127
# 1498  0.001740   18.464517  0.980740  479.347234  0.308725  326.214935
# 1499  0.003303   14.546463  0.961501  188.949583  0.341687  333.356969
#
#                f7        f8         f9       f10       f11       f12       f13
# ...

# %%
df_full.rename(columns= lambda x:'full_' + x, inplace = True)
df_full
# Out:
#        full_f1     full_f2   full_f3     full_f4   full_f5     full_f6  \
# 0     0.001354  659.317620  0.157167  391.132306  0.121252  346.768587
# 1     0.001497   91.209170  0.909179  502.079395  0.200690  358.785207
# 2     0.005265    3.084968  0.995852  371.720231  0.523585  357.885009
# 3     0.003159    4.283336  0.996857  681.378381  0.491811  413.949971
# 4     0.003536    2.498093  0.997002  416.623572  0.555521  406.948885
# ...        ...         ...       ...         ...       ...         ...
# 1495  0.001614   66.861090  0.950800  679.505644  0.215053  351.011115
# 1496  0.001704  364.121754  0.447507  329.527395  0.138495  332.144321
# 1497  0.001199   67.339221  0.949033  660.564422  0.211137  331.220127
# 1498  0.001740   18.464517  0.980740  479.347234  0.308725  326.214935
# 1499  0.003303   14.546463  0.961501  188.949583  0.341687  333.356969
#
#           full_f7   full_f8    full_f9  full_f10  full_f11  full_f12  full_f13
# ...

# %%
path_lst=[]
for f in glob.glob('Data(image)/train/leftbottom/*.jpg'): ###train_image改成放所有圖片的資料夾
    path_lst.append(f)

f1=f2=f3=f4=f5=f6=f7=f8=f9=f10=f11=f12=f13=np.empty(0)

for image in path_lst:
    img = cv2.imread(image)
    feature = mahotas.features.haralick(img).mean(axis =0)

    f1 = np.append(f1,feature[0])
    f2 = np.append(f2,feature[1])
    f3 = np.append(f3,feature[2])
    f4 = np.append(f4,feature[3])
    f5 = np.append(f5,feature[4])
    f6 = np.append(f6,feature[5])
    f7 = np.append(f7,feature[6])
    f8 = np.append(f8,feature[7])
    f9 = np.append(f9,feature[8])
    f10 = np.append(f10,feature[9])
    f11 = np.append(f11,feature[10])
    f12 = np.append(f12,feature[11])
    f13 = np.append(f13,feature[12])

# %%
df_lb = pd.DataFrame([f1,f2,f3,f4,f5,f6,f7,f8,f9,f10,f11,f12,f13], 
             index = ['f1','f2','f3','f4','f5','f6','f7','f8','f9','f10','f11','f12','f13']).transpose()

# %%
df_lb.rename(columns= lambda x:'lb_' + x, inplace = True)
df_lb
# Out:
#          lb_f1       lb_f2     lb_f3       lb_f4     lb_f5       lb_f6  \
# 0     0.001460  611.142506  0.119323  346.982075  0.122891  337.954625
# 1     0.001581   93.214872  0.888361  417.641001  0.196503  359.210731
# 2     0.007043    3.113188  0.995375  336.525297  0.523336  353.717896
# 3     0.003321    4.762602  0.996498  680.511685  0.483303  412.634491
# 4     0.003099    2.851437  0.997353  538.601450  0.537384  406.846609
# ...        ...         ...       ...         ...       ...         ...
# 1495  0.001450   83.628088  0.944137  748.429272  0.203152  386.798674
# 1496  0.001683  406.947536  0.256871  273.825692  0.133760  332.349996
# 1497  0.001325   67.231827  0.939606  556.685192  0.210749  333.852177
# 1498  0.001666   17.829295  0.984507  575.286555  0.311453  321.162348
# 1499  0.003292   14.522450  0.959804  180.747209  0.340171  333.264665
#
#             lb_f7     lb_f8      lb_f9    lb_f10    lb_f11    lb_f12    lb_f13
# ...

# %%
path_lst=[]
for f in glob.glob('Data(image)/train/lefttop/*.jpg'): ###train_image改成放所有圖片的資料夾
    path_lst.append(f)

f1=f2=f3=f4=f5=f6=f7=f8=f9=f10=f11=f12=f13=np.empty(0)

for image in path_lst:
    img = cv2.imread(image)
    feature = mahotas.features.haralick(img).mean(axis =0)

    f1 = np.append(f1,feature[0])
    f2 = np.append(f2,feature[1])
    f3 = np.append(f3,feature[2])
    f4 = np.append(f4,feature[3])
    f5 = np.append(f5,feature[4])
    f6 = np.append(f6,feature[5])
    f7 = np.append(f7,feature[6])
    f8 = np.append(f8,feature[7])
    f9 = np.append(f9,feature[8])
    f10 = np.append(f10,feature[9])
    f11 = np.append(f11,feature[10])
    f12 = np.append(f12,feature[11])
    f13 = np.append(f13,feature[12])

# %%
df_lt = pd.DataFrame([f1,f2,f3,f4,f5,f6,f7,f8,f9,f10,f11,f12,f13], 
             index = ['f1','f2','f3','f4','f5','f6','f7','f8','f9','f10','f11','f12','f13']).transpose()

# %%
df_lt.rename(columns= lambda x: 'lt_'+ x, inplace = True)
df_lt
# Out:
#          lt_f1       lt_f2     lt_f3       lt_f4     lt_f5       lt_f6  \
# 0     0.001427  628.711938  0.126095  359.720269  0.122036  350.929217
# 1     0.001287  102.691247  0.928404  717.020876  0.198995  363.483569
# 2     0.003981    3.211465  0.996527  462.283283  0.517230  372.070340
# 3     0.002680    3.972488  0.997081  680.961339  0.492997  409.720684
# 4     0.004202    2.378289  0.996013  298.545748  0.560548  413.878141
# ...        ...         ...       ...         ...       ...         ...
# 1495  0.001657   74.517080  0.940313  624.278118  0.207800  377.827078
# 1496  0.001672  414.799730  0.251413  277.045758  0.133570  327.564761
# 1497  0.001094   69.373448  0.956283  793.401399  0.209348  332.453911
# 1498  0.002169   18.885458  0.969771  312.382161  0.306032  331.734401
# 1499  0.003360   14.458180  0.960507  183.071402  0.342309  334.288699
#
#             lt_f7     lt_f8      lt_f9    lt_f10    lt_f11    lt_f12    lt_f13
# ...

# %%
path_lst=[]
for f in glob.glob('Data(image)/train/rightbottom/*.jpg'): ###train_image改成放所有圖片的資料夾
    path_lst.append(f)

f1=f2=f3=f4=f5=f6=f7=f8=f9=f10=f11=f12=f13=np.empty(0)

for image in path_lst:
    img = cv2.imread(image)
    feature = mahotas.features.haralick(img).mean(axis =0)

    f1 = np.append(f1,feature[0])
    f2 = np.append(f2,feature[1])
    f3 = np.append(f3,feature[2])
    f4 = np.append(f4,feature[3])
    f5 = np.append(f5,feature[4])
    f6 = np.append(f6,feature[5])
    f7 = np.append(f7,feature[6])
    f8 = np.append(f8,feature[7])
    f9 = np.append(f9,feature[8])
    f10 = np.append(f10,feature[9])
    f11 = np.append(f11,feature[10])
    f12 = np.append(f12,feature[11])
    f13 = np.append(f13,feature[12])

# %%
df_rb = pd.DataFrame([f1,f2,f3,f4,f5,f6,f7,f8,f9,f10,f11,f12,f13], 
             index = ['f1','f2','f3','f4','f5','f6','f7','f8','f9','f10','f11','f12','f13']).transpose()

# %%
df_rb.rename(columns= lambda x:'rb_' + x, inplace = True)
df_rb
# Out:
#          rb_f1       rb_f2     rb_f3       rb_f4     rb_f5       rb_f6  \
# 0     0.001349  677.068876  0.149680  398.124781  0.120550  341.916972
# 1     0.001740   82.562571  0.883343  353.908956  0.203607  356.286137
# 2     0.006882    2.893385  0.993349  217.668251  0.532579  344.808289
# 3     0.003499    4.302194  0.996611  635.155855  0.487667  419.748037
# 4     0.004195    2.290831  0.996602  337.281020  0.566799  398.082177
# ...        ...         ...       ...         ...       ...         ...
# 1495  0.002677   57.812529  0.830829  170.920784  0.221546  320.265423
# 1496  0.001832  303.161384  0.581122  361.825452  0.144569  332.011049
# 1497  0.001376   66.009060  0.936595  520.635955  0.211837  329.368175
# 1498  0.001664   17.757943  0.985448  610.305641  0.312038  315.583353
# 1499  0.003479   14.323238  0.961211  184.725554  0.344630  331.155853
#
#             rb_f7     rb_f8      rb_f9    rb_f10    rb_f11    rb_f12    rb_f13
# ...

# %%
path_lst=[]
for f in glob.glob('Data(image)/train/righttop/*.jpg'): ###train_image改成放所有圖片的資料夾
    path_lst.append(f)

f1=f2=f3=f4=f5=f6=f7=f8=f9=f10=f11=f12=f13=np.empty(0)

for image in path_lst:
    img = cv2.imread(image)
    feature = mahotas.features.haralick(img).mean(axis =0)

    f1 = np.append(f1,feature[0])
    f2 = np.append(f2,feature[1])
    f3 = np.append(f3,feature[2])
    f4 = np.append(f4,feature[3])
    f5 = np.append(f5,feature[4])
    f6 = np.append(f6,feature[5])
    f7 = np.append(f7,feature[6])
    f8 = np.append(f8,feature[7])
    f9 = np.append(f9,feature[8])
    f10 = np.append(f10,feature[9])
    f11 = np.append(f11,feature[10])
    f12 = np.append(f12,feature[11])
    f13 = np.append(f13,feature[12])

# %%
df_rt = pd.DataFrame([f1,f2,f3,f4,f5,f6,f7,f8,f9,f10,f11,f12,f13], 
             index = ['f1','f2','f3','f4','f5','f6','f7','f8','f9','f10','f11','f12','f13']).transpose()

# %%
df_rt.rename(columns= lambda x:'rt_' + x, inplace = True)
df_rt
# Out:
#          rt_f1       rt_f2     rt_f3       rt_f4     rt_f5       rt_f6  \
# 0     0.001329  720.343318  0.116250  407.576514  0.119539  356.231133
# 1     0.001523   86.733712  0.915632  513.919588  0.203567  356.427588
# 2     0.004513    3.145900  0.995798  374.375837  0.519206  361.372843
# 3     0.003573    4.136606  0.997128  720.421753  0.500857  413.792831
# 4     0.003513    2.491070  0.997311  463.488924  0.555160  408.820832
# ...        ...         ...       ...         ...       ...         ...
# 1495  0.002904   51.420268  0.836249  157.051226  0.227714  318.427446
# 1496  0.001702  330.791713  0.580618  394.384579  0.142197  336.673119
# 1497  0.001104   67.146578  0.956386  769.786398  0.212062  328.701037
# 1498  0.002083   19.495363  0.972586  355.595678  0.304206  335.920627
# 1499  0.003156   14.973059  0.963564  205.531570  0.338223  334.663182
#
#             rt_f7     rt_f8      rt_f9    rt_f10    rt_f11    rt_f12    rt_f13
# ...

# %%
df_rb.rename(columns= lambda x:'rb_' + x, inplace = True)
df_rb

# %%
df_f65 = pd.concat([df_full, df_lb, df_lt, df_rb, df_rt], axis =1)
df_f65
# Out:
#        full_f1     full_f2   full_f3     full_f4   full_f5     full_f6  \
# 0     0.001354  659.317620  0.157167  391.132306  0.121252  346.768587
# 1     0.001497   91.209170  0.909179  502.079395  0.200690  358.785207
# 2     0.005265    3.084968  0.995852  371.720231  0.523585  357.885009
# 3     0.003159    4.283336  0.996857  681.378381  0.491811  413.949971
# 4     0.003536    2.498093  0.997002  416.623572  0.555521  406.948885
# ...        ...         ...       ...         ...       ...         ...
# 1495  0.001614   66.861090  0.950800  679.505644  0.215053  351.011115
# 1496  0.001704  364.121754  0.447507  329.527395  0.138495  332.144321
# 1497  0.001199   67.339221  0.949033  660.564422  0.211137  331.220127
# 1498  0.001740   18.464517  0.980740  479.347234  0.308725  326.214935
# 1499  0.003303   14.546463  0.961501  188.949583  0.341687  333.356969
#
#           full_f7   full_f8    full_f9  full_f10  ...       rt_f4     rt_f5  \
# ...
